# %% [markdown]
# # Working with Simulation Directories
#
# Analyzing simulation data is as important as running the simulation itself. In this notebook, we will see how we easily access all the data using the [SimDir](../simdir.rst) module.
#
# (This notebook is meant to be converted in Sphinx documentation and not used directly.)

# %%
from kuibit import simdir as sd

# %% [markdown]
# Loading simulation data is as easy as generating `SimDir` objects. Just provide the path, and kuibit will do the rest.

# %%
sim = sd.SimDir("../../tests/tov")

# %% [markdown]
# We can get an overview of what is available by printing `sim`:

# %%
print(sim)
# Out:
# Indexed 454 files and 6 subdirectories
# Folder /home/runner/work/kuibit/kuibit/tests/tov
# /home/runner/work/kuibit/kuibit/tests/tov
# Available scalar timeseries:
# ['phi1', 'physical_time_per_hour', 'current_physical_time_per_hour', 'time_total', 'time_evolution', 'time_computing', 'time_communicating', 'time_io', 'evolution_steps_count', 'local_grid_points_per_second', 'total_grid_points_per_second', 'local_grid_point_updates_count', 'total_grid_point_updates_count', 'local_interior_points_per_second', 'total_interior_points_per_second', 'local_interior_point_updates_count', 'total_interior_point_updates_count', 'io_per_second', 'io_bytes_per_second', 'io_bytes_ascii_per_second', 'io_bytes_binary_per_second', 'io_count', 'io_bytes_count', 'io_bytes_ascii_count', 'io_bytes_binary_count', 'comm_per_second', 'comm_bytes_per_second', 'comm_count', 'comm_bytes_count', 'time_levels']
#
# Available minimum timeseries:
# ['press', 'rho', 'vel[0]', 'vel[1]', 'vel[2]', 'alp', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'eps', 'M1', 'M2', 'M3', 'H', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz']
#
# Available maximum timeseries:
# ['alp', 'H', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'vel[0]', 'vel[1]', 'vel[2]', 'M1', 'M2', 'M3', 'eps', 'rho', 'press', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz']
#
# Available norm1 timeseries:
# ['H', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'rho', 'eps', 'M1', 'M2', 'M3', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'alp', 'press', 'vel[0]', 'vel[1]', 'vel[2]']
#
# Available norm2 timeseries:
# ['press', 'rho', 'eps', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'M1', 'M2', 'M3', 'vel[0]', 'vel[1]', 'vel[2]', 'alp', 'H', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz']
#
# Available average timeseries:
# ['press', 'vel[0]', 'vel[1]', 'vel[2]', 'rho', 'H', 'alp', 'eps', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'M1', 'M2', 'M3', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz']
#
# Available sum timeseries:
# ['gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'vel[0]', 'vel[1]', 'vel[2]', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'H', 'rho', 'press', 'alp', 'M1', 'M2', 'M3', 'eps']
# Variables available: dict_keys(['harmonic', 'phi2', 'psi4'])
# For variable harmonic:
#
# Avilable radii: [4.0, 8.0]
#
# At radius 4.0, (l, m) available: [(0, 0), (1, -1), (1, 0), (1, 1), (2, -1), (2, -2), (2, 0), (2, 1), (2, 2)]
# At radius 8.0, (l, m) available: [(0, 0), (1, -1), (1, 0), (1, 1), (2, -1), (2, -2), (2, 0), (2, 1), (2, 2)]
#
# For variable phi2:
#
# Avilable radii: [77.93, 67.88, 91.46, 60.13, 48.95, 53.96, 110.69, 140.16, 191.0, 44.78]
#
# At radius 44.78, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 48.95, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 53.96, (l, m) available: [(2, -2), (2, -1), (2, 2), (2, 1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 60.13, (l, m) available: [(2, -2), (2, -1), (2, 2), (2, 0), (2, 1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 67.88, (l, m) available: [(2, -2), (2, 2), (2, 1), (2, -1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 77.93, (l, m) available: [(2, -2), (2, -1), (2, 1), (2, 2), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 91.46, (l, m) available: [(2, -1), (2, 1), (2, 2), (2, -2), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 110.69, (l, m) available: [(2, 0), (2, -1), (2, -2), (2, 1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 140.16, (l, m) available: [(2, 1), (2, -2), (2, 0), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 191.0, (l, m) available: [(2, -2), (2, 2), (2, -1), (2, 1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
#
# For variable psi4:
#
# Avilable radii: [110.69, 48.95, 53.96, 67.88, 140.16, 191.0, 91.46, 60.13, 77.93, 44.78]
#
# At radius 44.78, (l, m) available: [(2, 1), (2, 0), (2, -2), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 48.95, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 53.96, (l, m) available: [(2, 1), (2, -2), (2, -1), (2, 0), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 60.13, (l, m) available: [(2, -1), (2, -2), (2, 0), (2, 2), (2, 1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 67.88, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 77.93, (l, m) available: [(2, -2), (2, 1), (2, 0), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 91.46, (l, m) available: [(2, -1), (2, 1), (2, 0), (2, 2), (2, -2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 110.69, (l, m) available: [(2, -2), (2, 0), (2, 1), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 140.16, (l, m) available: [(2, 2), (2, 1), (2, 0), (2, -1), (2, -2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 191.0, (l, m) available: [(2, 1), (2, 0), (2, -2), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
#
# Available gravitational wave dataAvailable electromagnetic wave data
# Available grid data of dimension 1D (x):
# ['phi1', 'rho', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'H', 'alp', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'M1', 'M2', 'M3', 'eps', 'press', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (y):
# ['alp', 'M1', 'M2', 'M3', 'rho', 'eps', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'press', 'H', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (z):
# ['M1', 'M2', 'M3', 'alp', 'eps', 'press', 'rho', 'vel[0]', 'vel[1]', 'vel[2]', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'H']
#
#
# Available grid data of dimension 2D (xy):
# ['vel[0]', 'vel[2]', 'rho', 'vel[1]']
#
#
# Available grid data of dimension 2D (xz):
# ['vel[1]', 'vel[0]', 'vel[2]', 'rho']
#
#
# Available grid data of dimension 2D (yz):
# ['rho', 'vel[2]', 'vel[1]', 'vel[0]']
#
#
# Available grid data of dimension 3D (xyz):
# ['vel[2]', 'vel[0]', 'vel[1]', 'rho', 'mp_harmonic']
# No horizon found
# Timers available for processes [0, 1]
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting alp minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/alp.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-lapse.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting eps minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/hydrobase-eps.minimum.asc.bz2 with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/hydrobase-eps.minimum.asc.gz
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting eps minimum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/hydrobase-eps.minimum.asc.gz with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/hydrobase-eps.minimum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting vel[0] maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/hydrobase-vel.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/vel[0].maximum.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting alp maximum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-lapse.maximum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/alp.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting alp norm1 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-lapse.norm1.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/alp.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting alp norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-lapse.norm2.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/alp.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz norm2 from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm2.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting alp average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-lapse.average.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/alp.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz average from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.average.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz sum from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.sum.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxx infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxy infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kxz infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyy infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kyz infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(
# /home/runner/work/kuibit/kuibit/kuibit/cactus_scalars.py:403: RuntimeWarning: Overwriting kzz infnorm from /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.norm_inf.asc with /home/runner/work/kuibit/kuibit/tests/tov/output-0000/static_tov/admbase-curv.scalars.asc
#   warnings.warn(

# %% [markdown]
# This is a long output because we have a lot of available data! Everything that is printed is the output is easily accessible through `SimDir`. Moreover, the loading of data is lazy and the result is cached: computations are done only when needed, and all the subsequent calls will be immediate.
#
# If you have thorns with custom output, you have to extend `kuibit` to analyze them. `SimDir` has multiple submodules to handle the different kind of data. Let us explore them.

# %% [markdown]
# ## SimDir and pickles

# %% [markdown]
# `SimDir` performs some operations only when they needed. This work has be done every time the Python interpreter is killed. In some cases, it is useful to save the progress to files, resulting in faster execution times. This can be done with pickles. The simplest way to do so is as follows.

# %%
with sd.SimDir("../../tests/tov", pickle_file="/tmp/sim.pickle") as sim2:
    print(sim2)
# Out:
# Indexed 454 files and 6 subdirectories
# Folder /home/runner/work/kuibit/kuibit/tests/tov
# /home/runner/work/kuibit/kuibit/tests/tov
# Available scalar timeseries:
# ['phi1', 'physical_time_per_hour', 'current_physical_time_per_hour', 'time_total', 'time_evolution', 'time_computing', 'time_communicating', 'time_io', 'evolution_steps_count', 'local_grid_points_per_second', 'total_grid_points_per_second', 'local_grid_point_updates_count', 'total_grid_point_updates_count', 'local_interior_points_per_second', 'total_interior_points_per_second', 'local_interior_point_updates_count', 'total_interior_point_updates_count', 'io_per_second', 'io_bytes_per_second', 'io_bytes_ascii_per_second', 'io_bytes_binary_per_second', 'io_count', 'io_bytes_count', 'io_bytes_ascii_count', 'io_bytes_binary_count', 'comm_per_second', 'comm_bytes_per_second', 'comm_count', 'comm_bytes_count', 'time_levels']
#
# Available minimum timeseries:
# ['press', 'rho', 'vel[0]', 'vel[1]', 'vel[2]', 'alp', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'eps', 'M1', 'M2', 'M3', 'H', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz']
#
# Available maximum timeseries:
# ['alp', 'H', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'vel[0]', 'vel[1]', 'vel[2]', 'M1', 'M2', 'M3', 'eps', 'rho', 'press', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz']
#
# Available norm1 timeseries:
# ['H', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'rho', 'eps', 'M1', 'M2', 'M3', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'alp', 'press', 'vel[0]', 'vel[1]', 'vel[2]']
#
# Available norm2 timeseries:
# ['press', 'rho', 'eps', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'M1', 'M2', 'M3', 'vel[0]', 'vel[1]', 'vel[2]', 'alp', 'H', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz']
#
# Available average timeseries:
# ['press', 'vel[0]', 'vel[1]', 'vel[2]', 'rho', 'H', 'alp', 'eps', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'M1', 'M2', 'M3', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz']
#
# Available sum timeseries:
# ['gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'vel[0]', 'vel[1]', 'vel[2]', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'H', 'rho', 'press', 'alp', 'M1', 'M2', 'M3', 'eps']
# Variables available: dict_keys(['harmonic', 'phi2', 'psi4'])
# For variable harmonic:
#
# Avilable radii: [4.0, 8.0]
#
# At radius 4.0, (l, m) available: [(0, 0), (1, -1), (1, 0), (1, 1), (2, -1), (2, -2), (2, 0), (2, 1), (2, 2)]
# At radius 8.0, (l, m) available: [(0, 0), (1, -1), (1, 0), (1, 1), (2, -1), (2, -2), (2, 0), (2, 1), (2, 2)]
#
# For variable phi2:
#
# Avilable radii: [77.93, 67.88, 91.46, 60.13, 48.95, 53.96, 110.69, 140.16, 191.0, 44.78]
#
# At radius 44.78, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 48.95, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 53.96, (l, m) available: [(2, -2), (2, -1), (2, 2), (2, 1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 60.13, (l, m) available: [(2, -2), (2, -1), (2, 2), (2, 0), (2, 1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 67.88, (l, m) available: [(2, -2), (2, 2), (2, 1), (2, -1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 77.93, (l, m) available: [(2, -2), (2, -1), (2, 1), (2, 2), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 91.46, (l, m) available: [(2, -1), (2, 1), (2, 2), (2, -2), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 110.69, (l, m) available: [(2, 0), (2, -1), (2, -2), (2, 1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 140.16, (l, m) available: [(2, 1), (2, -2), (2, 0), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 191.0, (l, m) available: [(2, -2), (2, 2), (2, -1), (2, 1), (2, 0)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
#
# For variable psi4:
#
# Avilable radii: [110.69, 48.95, 53.96, 67.88, 140.16, 191.0, 91.46, 60.13, 77.93, 44.78]
#
# At radius 44.78, (l, m) available: [(2, 1), (2, 0), (2, -2), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 48.95, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 53.96, (l, m) available: [(2, 1), (2, -2), (2, -1), (2, 0), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 60.13, (l, m) available: [(2, -1), (2, -2), (2, 0), (2, 2), (2, 1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 67.88, (l, m) available: [(2, 0), (2, -2), (2, 1), (2, -1), (2, 2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 77.93, (l, m) available: [(2, -2), (2, 1), (2, 0), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 91.46, (l, m) available: [(2, -1), (2, 1), (2, 0), (2, 2), (2, -2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 110.69, (l, m) available: [(2, -2), (2, 0), (2, 1), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 140.16, (l, m) available: [(2, 2), (2, 1), (2, 0), (2, -1), (2, -2)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
# At radius 191.0, (l, m) available: [(2, 1), (2, 0), (2, -2), (2, 2), (2, -1)] (missing: [(1, 0), (1, 1), (1, -1), (0, 0)])
#
# Available gravitational wave dataAvailable electromagnetic wave data
# Available grid data of dimension 1D (x):
# ['phi1', 'rho', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'H', 'alp', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'M1', 'M2', 'M3', 'eps', 'press', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (y):
# ['alp', 'M1', 'M2', 'M3', 'rho', 'eps', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'press', 'H', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (z):
# ['M1', 'M2', 'M3', 'alp', 'eps', 'press', 'rho', 'vel[0]', 'vel[1]', 'vel[2]', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'H']
#
#
# Available grid data of dimension 2D (xy):
# ['vel[0]', 'vel[2]', 'rho', 'vel[1]']
#
#
# Available grid data of dimension 2D (xz):
# ['vel[1]', 'vel[0]', 'vel[2]', 'rho']
#
#
# Available grid data of dimension 2D (yz):
# ['rho', 'vel[2]', 'vel[1]', 'vel[0]']
#
#
# Available grid data of dimension 3D (xyz):
# ['vel[2]', 'vel[0]', 'vel[1]', 'rho', 'mp_harmonic']
# No horizon found
# Timers available for processes [0, 1]

# %% [markdown]
# When this code is run, `kuibit` checks if a pickle file exists in `/tmp/sim.pickle`. If yes, it will load it, effectively "resuming a previous session". At the end of the `with` block, the file is updated with the new work done. If the file did not exist initially, it will be created.
#
# It is important to be careful when working with pickles as the risk of stale objects is high. If the data is changing (e.g., new restarts are added), it is likely that it will result in errors.
#
# It is always possible to save the state of a `SimDir` using the `save` method and reads back the data with the `load_SimDir` function

# %%
sim.save("/tmp/saved.pickle") # The filename can be anything
sim3 = sd.load_SimDir("/tmp/saved.pickle")

# %% [markdown]
# ## `cactus_scalars`
# The [cactus_scalars](../cactus_scalars.rst) module understands ASCII files as output by CarpetASCII. It supports all the reductions (maximum, minimum, ...), 0d files, as well as scalar data. Using regular expression on the header of the file, `cactus_scalars` can process one variable per file and multiple variables per file. In `SimDir`, you can access scalars with the `ts` or `timeseries` attributes.

# %%
timeseries = sim.ts
# equivalent: timeseries = sim.timeseries

# %% [markdown]
# If we printed `timeseries`, we would find part of the output from `SimDir`. This is because the printed output from `SimDir` is obtained printing all the different submodules. Another way to see the available variable for a secific reduction is with the `keys` method:

# %%
timeseries.maximum.keys()
# Out:
# dict_keys(['alp', 'H', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'vel[0]', 'vel[1]', 'vel[2]', 'M1', 'M2', 'M3', 'eps', 'rho', 'press', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz'])

# %% [markdown]
# There are equivalent three different way to access those variables as [timeseries](../series.rst). The different methods are nearly equivalent.

# %%
rho_max1 = timeseries.maximum.fields.rho
rho_max2 = timeseries.maximum['rho']
rho_max3 = timeseries.maximum.get('rho')

# %% [markdown]
# These objects are [timeseries](../series.rst), which are extremely convienent representation of data evolving in time. These series span multiple simulation restarts and have files in different folders: `kuibit` does all the hard work to find the files and combine them. Moreover, they `timeseries` have a lot of features, as you can see in the [timeseries tutorial](timeseries.ipynb).

# %% [markdown]
# ## `cactus_multipoles` and `cactus_waves`

# %% [markdown]
# Gravitational waves are one of the most important quantities in numerical relativity simulations. Typically, these are computed using the Newman-Penrose formalism and extracted in terms of their multipolar components. `kuibit` fully supports the `Multipole` thorn with the [cactus_multipoles](../cactus_multipoles.rst) module. The `sim.multipoles` attribute contains multipolar data. This is a dictionary-like object with keys the various variable for which multipolar data is available.

# %%
print(sim.multipoles.keys())
# Out:
# dict_keys(['harmonic', 'phi2', 'psi4'])

# %% [markdown]
# Once a variable is selected, the returned object is once again a dictionary with keys the various extracion radii.

# %%
print(sim.multipoles["phi2"].keys())
phi2_0 = sim.multipoles["phi2"][91.46]

print(phi2_0.available_lm)
# Out:
# dict_keys([77.93, 67.88, 91.46, 60.13, 48.95, 53.96, 110.69, 140.16, 191.0, 44.78])
# {(2, -1), (2, -2), (2, 1), (2, 0), (2, 2)}

# %% [markdown]
# Selected the extraction radius, the variable contains all the various multipole l and m available. (HDF5 data is preferred in this.) Each component is then a timeseries.

# %%
phi2_0_22 = phi2_0[2,2]
print(type(phi2_0_22))
# Out:
# <class 'kuibit.timeseries.TimeSeries'>

# %% [markdown]
# Gravitational waves have a dedicated interface that is based on `cactus_multipole` and adds new specific features. Gravitational waves can be accessed with the `.gravitationalwaves` or `.gws` attributes.

# %%
psi4 = sim.gws

radius0 = psi4.radii[0]

# Example of specific function
print("Max GW power for l = 2, m = 2:", psi4[radius0].get_power_lm(2, 2, 100).max())
# Out:
# Max GW power for l = 2, m = 2: 1713.0809998152504

# %% [markdown]
# ## `cactus_grid_functions`
#
# The `.gridfunctions` (or `.gf`) attribute is used to access grid data, using the [cactus_grid_functions](../grid_data.rst) module. The structure is similar to time series.

# %%
print(sim.gf)
# Out:
# Available grid data of dimension 1D (x):
# ['phi1', 'rho', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'H', 'alp', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'M1', 'M2', 'M3', 'eps', 'press', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (y):
# ['alp', 'M1', 'M2', 'M3', 'rho', 'eps', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'press', 'H', 'vel[0]', 'vel[1]', 'vel[2]']
#
#
# Available grid data of dimension 1D (z):
# ['M1', 'M2', 'M3', 'alp', 'eps', 'press', 'rho', 'vel[0]', 'vel[1]', 'vel[2]', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz', 'kxx', 'kxy', 'kxz', 'kyy', 'kyz', 'kzz', 'H']
#
#
# Available grid data of dimension 2D (xy):
# ['vel[0]', 'vel[2]', 'rho', 'vel[1]']
#
#
# Available grid data of dimension 2D (xz):
# ['vel[1]', 'vel[0]', 'vel[2]', 'rho']
#
#
# Available grid data of dimension 2D (yz):
# ['rho', 'vel[2]', 'vel[1]', 'vel[0]']
#
#
# Available grid data of dimension 3D (xyz):
# ['vel[2]', 'vel[0]', 'vel[1]', 'rho', 'mp_harmonic']

# %%
# rest-mass density on the xy plane at iteration 0
rho = sim.gf.xy["rho"][0]

# %% [markdown]
# For more information of grid data, check out the [grid_data tutorial](grid_data.ipynb).

# %% [markdown]
# ## `cactus_horizons`
#
# `kuibit` can read horizon data from `QuasiLocalMeasures` and `AHFinderDirect`. The module that is responsible for this is [cactus_horizons](../cactus_horizons.rst). Horizon information is in the `.horizon` attribute.

# %% [markdown]
# ## `cactus_timers`
#
# If timing information is present, it can be accessed with the `.timers` attribute. This is provided by the [cactus_timers](../timers.rst) modules.
